# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
titanic['age'].fillna(titanic['age'].mean(),inplace=True)

# %%
titanic['embarked'].fillna(titanic['embarked'].mode()[0],inplace=True)

# %%
titanic['deck'].fillna(titanic['deck'].mode()[0],inplace=True)

# %%
titanic['embark_town'].fillna(titanic['embark_town'].mode()[0],inplace=True)

# %%
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
for col in titanic.columns:
    print(col)
# Out:
# survived
# pclass
# sex
# age
# sibsp
# parch
# fare
# embarked
# class
# who
# adult_male
# deck
# embark_town
# alive
# alone

# %%
sns.countplot(x='survived', data=titanic)
plt.title('Countplot of Survivors vs Non-Survivors')
# Out:
# Text(0.5, 1.0, 'Countplot of Survivors vs Non-Survivors')

# %%
sns.countplot(x="sex", data=titanic)  
plt.title('Countplot of male vs females')
# Out:
# Text(0.5, 1.0, 'Countplot of male vs females')

# %%
my_pal = {"First": "r", "Second": "b", "Third":"c"}
sns.boxplot(x='class', y='fare', data=titanic, palette=my_pal)
plt.show()

# %%
sns.histplot(data=titanic, x='age', kde=True,element="step", color='r')
plt.show()

# %%
sns.scatterplot(x='age', y='fare', hue='class',palette='flare', data=titanic)
plt.show()

# %%
sns.lmplot(x="pclass", y="fare",data=titanic)

# %%
sns.lmplot(x='age', y='fare', data=titanic, fit_reg=True, hue='sex', markers=['d', 'p'], height=8)
plt.title('Scatterplot of Age and Fare by Sex')
plt.show()

# %%
my_pal = {"First": "r", "Second": "b", "Third":"c"}
sns.countplot(x='class', saturation=1,palette=my_pal,orient='h',data=titanic)
plt.title('Number of Passengers by Class')
plt.show()

# %%
sns.displot(data=titanic, x="age", y="fare",height=7)

# %%
sns.set(rc={'figure.figsize':(20,15)})
plt.subplot(3,4,1)
sns.histplot(titanic['fare'], color="yellow",kde=True)
plt.title('Histogram of Ticket Price')
plt.xlabel('Ticket Price', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.grid()

plt.subplot(3,4,2)
sns.histplot(titanic['age'],kde=True,color="orange")
plt.title('Histogram of Age')
plt.xlabel('Age', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.grid()

plt.subplot(3,4,3)
sns.histplot(titanic['fare'],kde=False,color="darkblue")
plt.title('Histogram of Fare')
plt.xlabel('Fare', fontsize = 12)
plt.ylabel('Frequency', fontsize = 12)
plt.grid()

plt.suptitle('Different Histograms', fontsize = 20)
plt.show()

# %%
# Create a new column 'age_group' to categorize passengers by age
titanic['age_group'] = pd.cut(titanic['age'], bins=[0, 18, 30, 50, 100], labels=['Child', 'Young Adult', 'Middle Aged', 'Elderly'])

# Calculate the survival rate for each age group
age_group_survival = titanic.groupby('age_group')['survived'].mean().reset_index()

# Create a bar plot of the survival rate by age group
sns.barplot(x='age_group', y='survived', data=age_group_survival)
plt.title('Survival Rate by Age Group',fontsize = 25)
plt.xlabel('Age Group',fontsize = 20)
plt.ylabel('Survival Rate',fontsize = 20)
plt.show()

# %%
# Create a cross tabulation table of age group and survival
survival_table = pd.crosstab(titanic['age_group'], titanic['survived'], values=titanic['survived'], aggfunc='count')
survival_table
# Out:
# survived       0    1
# age_group
# Child         69   70
# Young Adult  299  148
# Middle Aged  139  102
# Elderly       42   22

# %%
# Rename the column labels
survival_table.columns = ['Did not survive', 'Survived']
# Create a bar plot of the survival count by age group
sns.barplot(x=survival_table.index, y='Survived', data=survival_table)
plt.title('Survival Count by Age Group',fontsize = 25)
plt.xlabel('Age Group',fontsize = 20)
plt.ylabel('Survival Count',fontsize = 20)
plt.show()

# %%
sns.barplot(x=survival_table.index, y='Survived', data=survival_table, color='green', label='Survived')

sns.barplot(x=survival_table.index, y='Did not survive', data=survival_table, color='red', label='Did not survive', bottom=survival_table['Survived'])

plt.title('Survival and Death Count by Age Group',fontsize = 25)

plt.xlabel('Age Group',fontsize = 20)
plt.ylabel('Count',fontsize = 20)
plt.legend(fontsize = 25)
plt.show()
