# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# Reading the csv file:

# %%
new = pd.read_csv("online_store_customer_data.csv")
new
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      1.0
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 0          2051.36
# 1           544.04
# 2          1572.60
# 3          1199.79
# 4              NaN
# ...            ...
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15
#
# [2512 rows x 11 columns]

# %%
new.dtypes
# Out:
# Transaction_date     object
# Transaction_ID        int64
# Gender               object
# Age                 float64
# Marital_status       object
# State_names          object
# Segment              object
# Employees_status     object
# Payment_method       object
# Referal             float64
# Amount_spent        float64
# dtype: object

# %%
# group by Gender and calculate the mean, median, min, max, and standard deviation of Amount spent
grouped_data = new.groupby("Gender")["Amount_spent"].agg(["mean", "median", "min", "max", "std"])

# print the summary statistics for each Gender group
grouped_data
# Out:
#                mean   median   min      max         std
# Gender
# Female  1429.031627  1357.60  2.09  2999.98  883.354685
# Male    1407.716397  1313.94  2.16  2998.62  874.123667

# %%
# group by Gender and calculate the mean, median, min, max, and standard deviation of Age
grouped_data2 = new.groupby("Gender")["Age"].agg(["mean", "median", "min", "max", "std"])

# print the summary statistics for each Gender group
grouped_data2
# Out:
#              mean  median   min   max        std
# Gender
# Female  46.864253    47.0  15.0  78.0  18.251732
# Male    46.475806    47.0  15.0  78.0  18.123452

# %%
# group by Martial status and calculate the mean, median, min, max, and standard deviation of amount spend
grouped_data3 = new.groupby("Marital_status")["Amount_spent"].agg(["mean", "median", "min", "max", "std"])

# print the summary statistics for marital_status grp
grouped_data3
# Out:
#                        mean   median   min      max         std
# Marital_status
# Married         1414.961412  1297.82  2.09  2999.98  879.685573
# Single          1423.328658  1390.46  2.16  2997.21  877.279900

# %%
# group by Maritial status and calculate the mean, median, min, max, and standard deviation of age
grouped_data4 = new.groupby("Marital_status")["Age"].agg(["mean", "median", "min", "max", "std"])

# print the summary statistics for marital_status grp
grouped_data4
# Out:
#                      mean  median   min   max        std
# Marital_status
# Married         46.459889    47.0  15.0  78.0  18.268948
# Single          46.888672    46.5  15.0  78.0  18.074823

# %%
